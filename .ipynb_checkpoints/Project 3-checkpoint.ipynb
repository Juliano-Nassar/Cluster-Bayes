# %% [markdown]
# # SVMons - Analisando o mundo Pokemon com SVM
#
# ## Informações do Projeto
#
# Prazo: 21/Nov até às 23:59.<br />
# Grupo: José Hélio Paiva - Juliano Nassar<br /><br />
# Entregamos via GitHub:
# * https://github.com/Juliano-Nassar/Cluster-Bayes
#
# ## Introdução
#
# Inicialmente pensamos em fazer esse projeto com o intuito de aumentar nosso conhecimento em Naive Bayes e aprender um pouco de uma ferramenta que achamos que será útil em projetos futuros a cauterização, além de pensarmos também em resolver um problema que está se tornando bem recorrente no meio bancário, que são as fraudes bancarias, e acreditávamos que se fizéssemos um bom trabalho com esse projeto isso poderia significar uma porta nova se abrindo para um futuro estagio. Porém, perdemos muito tempo estudando o Dataset e procurando um meio de entender melhor o que ele estava dizendo, pois tinham informações muito importantes que o banco não pôde liberar o significado delas no Dataset. Então decidimos mudar de data frame 1 semana e meia antes da entrega do trabalho.
#
# Dessa forma pegamos esse Dataset de Pokémon pois queríamos relembrar um pouco o segundo projeto de Design de Software e achamos que seria interessante analisar a forma como um dos jogos mais jogados do mundo se comporta com relação a sua formação de Pokémon. Gostaríamos de saber se algumas características dos Pokémon como o fato de serem lendários ou não podem ser encontrados através da análise dos atributos de **Hit Point (HP), Attack, Defense, Sp. Atk, Sp. Def, Speed**. O que muitos podem pensar é que pelo fato de termos uma Coluna chamada Total (Total de pontos) ela mostra se ele é lendário ou não. Porém, o que dificulta nosso trabalho é o fato de termos Pokémon Lendários bem mais fracos que uma grande maioria de Pokémon. Assim, fazendo com que precisemos usar nossos conhecimentos de Machine Learn para solucionar esse mistério.
# <br /><br />
# Inicialmente, pensamos em fazer uma análise com Bayes e cauterização, porem como o nosso tempo era curto e tivemos outros projetos na mesma época, optamos por usar uma função da biblioteca scikit-learn chamada SVM (Support Vectors Machine). Essa função pelo que pesquisamos utiliza Gradiente descendente que cria um plano entre duas classes de dados com as margens entre eles maximizadas, a esse plano da se o nome de Hyperplano.

# %% [markdown]
# ## Estudando SVM
#
# Sabíamos que não teríamos muito tempo para cometer mais erros então optamos por não deixar caixas pretas com relação a esse assunto durante o projeto. Tiramos 3 dias inteiros para estudar sobre como o SVM trabalha e o que essa função faz por traz dos holofotes. Achamos diversos materiais que nos ajudaram a entender que o SVM usa Loss function e Objective function para definir o melhor fit para as classes de dados através de Gradiente descendente. O Hyperplano pode ser encontrado em diversas dimensões, tendo essas dimensões interpretadas como a dimensão do gráfico menos uma dimensão. Ou seja, se o gráfico é bidimensional o Hyperplano é uma reta, se o gráfico é tridimensional ele é um plano.
#
# Independentemente da quantidade de dimensões que esses dados possam ter, sempre é possível representar em forma de Hyperplano. As vezes essas separações em 2D não se pareciam muito com retas, então usamos técnicas de classificação não linear para acrescentar mais uma dimensão ao gráfico e achar um Hyperplano entre eles.
#
#
# Support Vector Machines - The Math of Intelligence
# https://www.youtube.com/watch?v=g8D5YL6cOSE&t=26s
#
# In-Depth: Support Vector Machines
# https://jakevdp.github.io/PythonDataScienceHandbook/05.07-support-vector-machines.html
#
# Support vector machines (SVMs) - Documentation
# http://scikit-learn.org/stable/modules/svm.html

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#Create Database
PokeData = pd.read_csv("Pokemon.csv")

n = int(len(PokeData)/2)
PokeData.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Legendary -1  
#not legendary -0
def Legend(i):
    if i:
        return 1
    else:
        return 0
    
PokeData["Legendary"] = PokeData["Legendary"].apply(Legend)
PokeData.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
#Training and testing data
PokeTeste = PokeData[:n]
PokeTreino = PokeData[n:]

# %%
#Filter only the important columns
StatsTreino = PokeTreino.loc[:,["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]
StatsTeste = PokeTeste.loc[:,["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]
StatsTreino.head()
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 400  110      80       90       95       90     65
# 401   35      64       85       74       55     32
# 402   55     104      105       94       75     52
# 403   55      84      105      114       75     52
# 404  100      90      130       45       65     55

# %%
#Linear classifier
from sklearn import svm
Classificador = svm.SVC(kernel='linear', C=1)
Classificador.fit(StatsTreino,PokeTreino["Legendary"])
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Testing linear classifier
ListaTeste = Classificador.predict(StatsTeste)

#Real values
x = PokeTeste.Legendary

#Comparing values
contador = 0
h = 0
for i in ListaTeste:
    if i == x[h]:
        contador+=1
    h+=1
    
prob = contador/len(x)
print("Prob of getting right: {0}".format(prob))
# Out:
# Prob of getting right: 0.9275

# %%
#Exponencial classifier
Classificador = svm.SVC(kernel='rbf',C = 1e6)
Classificador.fit(StatsTreino,PokeTreino["Legendary"])
# Out:
# SVC(C=1000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Testing exponencial classifier
Teste = Classificador.predict(StatsTeste)

#Real values
x = PokeTeste.Legendary

#Comparing values
contador = 0
h = 0

for i in Teste:
    if i == x[h]:
        contador+=1
    h+=1
    
prob = contador/len(x)
print("Prob of getting right: {0}".format(prob))
# Out:
# Prob of getting right: 0.9675

# %%
#Formatting type 1
#Water - 1
#Normal - 2
# ...
def Classes(i):
        lista = [
"Water",       
"Normal",       
"Grass" ,       
"Bug" ,         
"Psychic",      
"Fire",         
"Electric",     
"Rock",         
"Ground",       
"Dragon",       
"Ghost",        
"Dark",         
"Poison",       
"Fighting",     
"Steel",        
"Ice",         
"Fairy",       
"Flying" 
        ]
        
        contador = 1
        for h in lista:
            if i == h:
                return contador
            contador+= 1
PokeData["Type 1"] = PokeData["Type 1"].apply(Classes)
PokeData.head()
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur       3  Poison    318  45      49       49
# 1  2                Ivysaur       3  Poison    405  60      62       63
# 2  3               Venusaur       3  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur       3  Poison    625  80     100      123
# 4  4             Charmander       6     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
#Training and testing data
PokeTeste = PokeData[:n]
PokeTreino = PokeData[n:]

StatsTreino = PokeTreino.loc[:,["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]
StatsTeste = PokeTeste.loc[:,["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"]]

# %%
#Multi-Class classifier
Classificador = svm.SVC(decision_function_shape='ovr',kernel='linear')
Classificador.fit(StatsTreino,PokeTreino["Type 1"])
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Testing Multi-Class classifier
Teste = Classificador.predict(StatsTeste)

#Real values
x = PokeTeste["Type 1"]

#Comparing values
contador = 0
h = 0

for i in Teste:
    if i == x[h]:
        contador+=1
    h+=1

prob = contador/len(x)
print("Prob of getting right: {0}".format(prob))
# Out:
# Prob of getting right: 0.2375
